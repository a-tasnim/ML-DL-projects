# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
#IoT Fridge
data = pd.read_csv('/content/drive/MyDrive/ToN_IoT_dataset/Processed_IoT_dataset/IoT_Fridge.csv')

# %%
data
# Out:
#              date            time  ...  label    type
# 0       31-Mar-19     12:36:52     ...      0  normal
# 1       31-Mar-19     12:36:53     ...      0  normal
# 2       31-Mar-19     12:36:54     ...      0  normal
# 3       31-Mar-19     12:36:55     ...      0  normal
# 4       31-Mar-19     12:36:56     ...      0  normal
# ...           ...             ...  ...    ...     ...
# 587071  27-Apr-19       12:41:17   ...      0  normal
# 587072  27-Apr-19       12:41:17   ...      0  normal
# 587073  27-Apr-19       12:41:17   ...      0  normal
# 587074  27-Apr-19       12:41:18   ...      0  normal
# 587075  27-Apr-19       12:41:20   ...      0  normal
#
# [587076 rows x 6 columns]

# %%
print(data.shape)
print("No of rows",data.shape[0])
print("No of columns",data.shape[1])
# Out:
# (587076, 6)
# No of rows 587076
# No of columns 6

# %%
inputs = data.drop(['label','type'],axis = 'columns')
target_var = data['label']

# %%
inputs
# Out:
#              date            time  fridge_temperature temp_condition
# 0       31-Mar-19     12:36:52                  13.10          high
# 1       31-Mar-19     12:36:53                   8.65          high
# 2       31-Mar-19     12:36:54                   2.00           low
# 3       31-Mar-19     12:36:55                   4.80           low
# 4       31-Mar-19     12:36:56                  10.70          high
# ...           ...             ...                 ...            ...
# 587071  27-Apr-19       12:41:17                 4.00            low
# 587072  27-Apr-19       12:41:17                 6.05           high
# 587073  27-Apr-19       12:41:17                12.80           high
# 587074  27-Apr-19       12:41:18                 6.50           high
# 587075  27-Apr-19       12:41:20                 5.30            low
#
# [587076 rows x 4 columns]

# %%
le_date = LabelEncoder()
le_time = LabelEncoder()
le_fridge_temperature = LabelEncoder()
le_temp_condition = LabelEncoder()

# %%
inputs['date_n'] = le_date.fit_transform(inputs['date'])
inputs['time_n'] = le_time.fit_transform(inputs['time'])
inputs['fridge_temperature_n'] = le_fridge_temperature.fit_transform(inputs['fridge_temperature'])
inputs['temp_condition_n'] = le_temp_condition.fit_transform(inputs['temp_condition'])
inputs.head()
# Out:
#         date            time  ...  fridge_temperature_n temp_condition_n
# 0  31-Mar-19     12:36:52     ...                   144                1
# 1  31-Mar-19     12:36:53     ...                    94                1
# 2  31-Mar-19     12:36:54     ...                     7                4
# 3  31-Mar-19     12:36:55     ...                    40                4
# 4  31-Mar-19     12:36:56     ...                   117                1
#
# [5 rows x 8 columns]

# %%
new_inputs = inputs.drop(['date','time','fridge_temperature','temp_condition'],axis = 'columns')
new_inputs.head()
# Out:
#    date_n  time_n  fridge_temperature_n  temp_condition_n
# 0      11   10707                   144                 1
# 1      11   10708                    94                 1
# 2      11   10709                     7                 4
# 3      11   10710                    40                 4
# 4      11   10711                   117                 1

# %%
#split dataset in features and target variable
feature_cols = ['date_n', 'time_n', 'fridge_temperature_n', 'temp_condition_n']
X = new_inputs[feature_cols] # Features
y = target_var # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(6,5),random_state=5,verbose=True,learning_rate_init=0.01)


# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 0.16664218
# Iteration 2, loss = 0.13772462
# Iteration 3, loss = 0.12867478
# Iteration 4, loss = 0.12672527
# Iteration 5, loss = 0.11857852
# Iteration 6, loss = 0.07760700
# Iteration 7, loss = 0.06848886
# Iteration 8, loss = 0.06319401
# Iteration 9, loss = 0.06107001
# Iteration 10, loss = 0.06009460
# Iteration 11, loss = 0.05817869
# Iteration 12, loss = 0.05555789
# Iteration 13, loss = 0.05421276
# Iteration 14, loss = 0.05385753
# Iteration 15, loss = 0.05286739
# Iteration 16, loss = 0.05276597
# Iteration 17, loss = 0.05226779
# Iteration 18, loss = 0.05203342
# Iteration 19, loss = 0.05167875
# Iteration 20, loss = 0.05190594
# Iteration 21, loss = 0.05171586
# Iteration 22, loss = 0.05128139
# Iteration 23, loss = 0.05148834
# Iteration 24, loss = 0.05101941
# Iteration 25, loss = 0.05071165
# Iteration 26, loss = 0.05076112
# Iteration 27, loss = 0.05036616
# Iteration 28, loss = 0.05039008
# Iteration 29, loss = 0.05027478
# Iteration 30, loss = 0.05038414
# Iteration 31, loss = 0.05028713
# Iteration 32, loss = 0.05038844
# Iteration 33, loss = 0.05035699
# Iteration 34, loss = 0.05018720
# Iteration 35, loss = 0.05001086
# Iteration 36, loss = 0.05005740
# Iteration 37, loss = 0.05030825
# Iteration 38, loss = 0.05025661
# Iteration 39, loss = 0.05001668
# Iteration 40, loss = 0.05011059
# Iteration 41, loss = 0.05014980
# Iteration 42, loss = 0.05024790
# Iteration 43, loss = 0.05010606
# Iteration 44, loss = 0.05015867
# Iteration 45, loss = 0.05020430
# Iteration 46, loss = 0.05056407
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9789862766362145

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['True Pos','False Pos','False Neg','True Neg']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(conf_matrix, annot=labels, fmt="", cmap='Blues')
ax.xaxis.set_ticklabels([1,0])
ax.yaxis.set_ticklabels([1,0])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    150423
#            1       0.89      0.97      0.93     25700
#
#     accuracy                           0.98    176123
#    macro avg       0.94      0.98      0.96    176123
# weighted avg       0.98      0.98      0.98    176123

# %%
#IoT GPS tracker
data = pd.read_csv('/content/drive/MyDrive/ToN_IoT_dataset/Processed_IoT_dataset/IoT_GPS_Tracker.csv')

# %%
data
# Out:
#              date        time    latitude   longitude  label    type
# 0       31-Mar-19    12:36:52    0.000000   10.000000      0  normal
# 1       31-Mar-19    12:36:53    0.000000   10.000000      0  normal
# 2       31-Mar-19    12:36:54    0.000000   10.000000      0  normal
# 3       31-Mar-19    12:36:55    0.000000   10.000000      0  normal
# 4       31-Mar-19    12:36:56    0.000000   10.000000      0  normal
# ...           ...         ...         ...         ...    ...     ...
# 595681  27-Apr-19   12:41:16   182.523268  190.867134      0  normal
# 595682  27-Apr-19   12:41:16   183.122818  191.159551      0  normal
# 595683  27-Apr-19   12:41:17   247.820755  261.905963      0  normal
# 595684  27-Apr-19   12:41:17   246.000741  264.091992      0  normal
# 595685  27-Apr-19   12:41:18   180.896829  193.602285      0  normal
#
# [595686 rows x 6 columns]

# %%
print(data.shape)
print("No of rows",data.shape[0])
print("No of columns",data.shape[1])
# Out:
# (595686, 6)
# No of rows 595686
# No of columns 6

# %%
inputs = data.drop(['label','type'],axis = 'columns')
target_var = data['label']
inputs
# Out:
#              date        time    latitude   longitude
# 0       31-Mar-19    12:36:52    0.000000   10.000000
# 1       31-Mar-19    12:36:53    0.000000   10.000000
# 2       31-Mar-19    12:36:54    0.000000   10.000000
# 3       31-Mar-19    12:36:55    0.000000   10.000000
# 4       31-Mar-19    12:36:56    0.000000   10.000000
# ...           ...         ...         ...         ...
# 595681  27-Apr-19   12:41:16   182.523268  190.867134
# 595682  27-Apr-19   12:41:16   183.122818  191.159551
# 595683  27-Apr-19   12:41:17   247.820755  261.905963
# 595684  27-Apr-19   12:41:17   246.000741  264.091992
# 595685  27-Apr-19   12:41:18   180.896829  193.602285
#
# [595686 rows x 4 columns]

# %%
le_date = LabelEncoder()
le_time = LabelEncoder()
le_latitude = LabelEncoder()
le_longitude = LabelEncoder()

# %%
inputs['date_n'] = le_date.fit_transform(inputs['date'])
inputs['time_n'] = le_time.fit_transform(inputs['time'])
inputs['latitude_n'] = le_latitude.fit_transform(inputs['latitude'])
inputs['longitude_n'] = le_longitude.fit_transform(inputs['longitude'])
inputs.head()
# Out:
#         date      time  latitude  ...  time_n  latitude_n  longitude_n
# 0  31-Mar-19  12:36:52       0.0  ...   84384           0            0
# 1  31-Mar-19  12:36:53       0.0  ...   84385           0            0
# 2  31-Mar-19  12:36:54       0.0  ...   84386           0            0
# 3  31-Mar-19  12:36:55       0.0  ...   84387           0            0
# 4  31-Mar-19  12:36:56       0.0  ...   84388           0            0
#
# [5 rows x 8 columns]

# %%
new_inputs = inputs.drop(['date','time','latitude','longitude'],axis = 'columns')
new_inputs.head()
# Out:
#    date_n  time_n  latitude_n  longitude_n
# 0      11   84384           0            0
# 1      11   84385           0            0
# 2      11   84386           0            0
# 3      11   84387           0            0
# 4      11   84388           0            0

# %%
#split dataset in features and target variable
feature_cols = ['date_n', 'time_n', 'latitude_n', 'longitude_n']
X = new_inputs[feature_cols] # Features
y = target_var # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(6,5),random_state=5,verbose=True,learning_rate_init=0.01)


# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 0.13435140
# Iteration 2, loss = 0.07874031
# Iteration 3, loss = 0.06784988
# Iteration 4, loss = 0.06789971
# Iteration 5, loss = 0.06637999
# Iteration 6, loss = 0.06537023
# Iteration 7, loss = 0.06499087
# Iteration 8, loss = 0.06399280
# Iteration 9, loss = 0.06434494
# Iteration 10, loss = 0.06398699
# Iteration 11, loss = 0.06390963
# Iteration 12, loss = 0.06370279
# Iteration 13, loss = 0.06376192
# Iteration 14, loss = 0.06366145
# Iteration 15, loss = 0.06373333
# Iteration 16, loss = 0.06344426
# Iteration 17, loss = 0.06289308
# Iteration 18, loss = 0.06366255
# Iteration 19, loss = 0.06327458
# Iteration 20, loss = 0.06340619
# Iteration 21, loss = 0.06296232
# Iteration 22, loss = 0.06334314
# Iteration 23, loss = 0.06303969
# Iteration 24, loss = 0.06335716
# Iteration 25, loss = 0.06269960
# Iteration 26, loss = 0.06293348
# Iteration 27, loss = 0.06318633
# Iteration 28, loss = 0.06281831
# Iteration 29, loss = 0.06301234
# Iteration 30, loss = 0.06276856
# Iteration 31, loss = 0.06273862
# Iteration 32, loss = 0.06261427
# Iteration 33, loss = 0.06293034
# Iteration 34, loss = 0.06308475
# Iteration 35, loss = 0.06269199
# Iteration 36, loss = 0.06279779
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9759661119380435

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['True Positive','False Positive','False Negative','True Negative']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(conf_matrix, annot=labels, fmt="", cmap='Blues')
ax.xaxis.set_ticklabels([1,0])
ax.yaxis.set_ticklabels([1,0])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99    154191
#            1       0.92      0.90      0.91     24515
#
#     accuracy                           0.98    178706
#    macro avg       0.95      0.94      0.95    178706
# weighted avg       0.98      0.98      0.98    178706

# %%
#IoT Garage Door
data = pd.read_csv('/content/drive/MyDrive/ToN_IoT_dataset/Processed_IoT_dataset/IoT_Garage_Door.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#              date           time door_state sphone_signal  label    type
# 0        1-Apr-19    20:53:44          open        true        0  normal
# 1        1-Apr-19    20:53:49        closed       false        0  normal
# 2        1-Apr-19    20:53:49          open        true        0  normal
# 3        1-Apr-19    20:53:54        closed       false        0  normal
# 4        1-Apr-19    20:53:54          open        true        0  normal
# ...           ...            ...        ...           ...    ...     ...
# 591441  27-Apr-19      11:03:21      closed           0.0      0  normal
# 591442  27-Apr-19      11:03:21      closed           0.0      0  normal
# 591443  27-Apr-19      11:03:21      closed           0.0      0  normal
# 591444  27-Apr-19      11:03:22      closed           0.0      0  normal
# 591445  27-Apr-19      11:03:24      closed           0.0      0  normal
#
# [591446 rows x 6 columns]

# %%
print(data.shape)
print("No of rows",data.shape[0])
print("No of columns",data.shape[1])
# Out:
# (591446, 6)
# No of rows 591446
# No of columns 6

# %%
inputs = data.drop(['label','type'],axis = 'columns')
target_var = data['label']
inputs
# Out:
#              date           time door_state sphone_signal
# 0        1-Apr-19    20:53:44          open        true
# 1        1-Apr-19    20:53:49        closed       false
# 2        1-Apr-19    20:53:49          open        true
# 3        1-Apr-19    20:53:54        closed       false
# 4        1-Apr-19    20:53:54          open        true
# ...           ...            ...        ...           ...
# 591441  27-Apr-19      11:03:21      closed           0.0
# 591442  27-Apr-19      11:03:21      closed           0.0
# 591443  27-Apr-19      11:03:21      closed           0.0
# 591444  27-Apr-19      11:03:22      closed           0.0
# 591445  27-Apr-19      11:03:24      closed           0.0
#
# [591446 rows x 4 columns]

# %%
le_date = LabelEncoder()
le_time = LabelEncoder()
le_door_state = LabelEncoder()
le_sphone_signal = LabelEncoder()

# %%
inputs['date_n'] = le_date.fit_transform(inputs['date'].astype('str'))
inputs['time_n'] = le_time.fit_transform(inputs['time'].astype('str'))
inputs['door_state_n'] = le_door_state.fit_transform(inputs['door_state'].astype('str'))
inputs['sphone_signal_n'] = le_sphone_signal.fit_transform(inputs['sphone_signal'].astype('str'))
inputs.head()
# Out:
#        date           time door_state  ... time_n  door_state_n  sphone_signal_n
# 0  1-Apr-19    20:53:44          open  ...  28286             2                6
# 1  1-Apr-19    20:53:49        closed  ...  28287             0                4
# 2  1-Apr-19    20:53:49          open  ...  28287             2                6
# 3  1-Apr-19    20:53:54        closed  ...  28288             0                4
# 4  1-Apr-19    20:53:54          open  ...  28288             2                6
#
# [5 rows x 8 columns]

# %%
new_inputs = inputs.drop(['date','time','door_state','sphone_signal'],axis = 'columns')
new_inputs.head()
# Out:
#    date_n  time_n  door_state_n  sphone_signal_n
# 0       0   28286             2                6
# 1       0   28287             0                4
# 2       0   28287             2                6
# 3       0   28288             0                4
# 4       0   28288             2                6

# %%
#split dataset in features and target variable
feature_cols = ['date_n', 'time_n', 'door_state_n', 'sphone_signal_n']
X = new_inputs[feature_cols] # Features
y = target_var # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(6,5),random_state=5,verbose=True,learning_rate_init=0.01)


# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 0.13005483
# Iteration 2, loss = 0.10761940
# Iteration 3, loss = 0.10207626
# Iteration 4, loss = 0.08528564
# Iteration 5, loss = 0.06617726
# Iteration 6, loss = 0.06390245
# Iteration 7, loss = 0.06328788
# Iteration 8, loss = 0.06257982
# Iteration 9, loss = 0.06241898
# Iteration 10, loss = 0.06184438
# Iteration 11, loss = 0.05814423
# Iteration 12, loss = 0.05769894
# Iteration 13, loss = 0.05778511
# Iteration 14, loss = 0.05743909
# Iteration 15, loss = 0.05745190
# Iteration 16, loss = 0.05728954
# Iteration 17, loss = 0.05710477
# Iteration 18, loss = 0.05423186
# Iteration 19, loss = 0.05264763
# Iteration 20, loss = 0.05180598
# Iteration 21, loss = 0.05150334
# Iteration 22, loss = 0.05118748
# Iteration 23, loss = 0.05051063
# Iteration 24, loss = 0.05070759
# Iteration 25, loss = 0.05027813
# Iteration 26, loss = 0.05025516
# Iteration 27, loss = 0.05010704
# Iteration 28, loss = 0.05027375
# Iteration 29, loss = 0.05000567
# Iteration 30, loss = 0.05012319
# Iteration 31, loss = 0.05009864
# Iteration 32, loss = 0.05006568
# Iteration 33, loss = 0.04973304
# Iteration 34, loss = 0.04994671
# Iteration 35, loss = 0.04961530
# Iteration 36, loss = 0.04972549
# Iteration 37, loss = 0.04989806
# Iteration 38, loss = 0.04988439
# Iteration 39, loss = 0.04993852
# Iteration 40, loss = 0.04993146
# Iteration 41, loss = 0.04958226
# Iteration 42, loss = 0.04956641
# Iteration 43, loss = 0.04974148
# Iteration 44, loss = 0.04972481
# Iteration 45, loss = 0.04963424
# Iteration 46, loss = 0.04966574
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9836615304845745

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['True Positive','False Positive','False Negative','True Negative']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(conf_matrix, annot=labels, fmt="", cmap='Blues')
ax.xaxis.set_ticklabels([1,0])
ax.yaxis.set_ticklabels([1,0])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    154691
#            1       0.96      0.91      0.93     22743
#
#     accuracy                           0.98    177434
#    macro avg       0.97      0.95      0.96    177434
# weighted avg       0.98      0.98      0.98    177434

# %%
#IoT Modbus
data = pd.read_csv('/content/drive/MyDrive/ToN_IoT_dataset/Processed_IoT_dataset/IoT_Modbus.csv')

# %%
data
# Out:
#              date        time  ...  label    type
# 0       31-Mar-19   12:36:55   ...      0  normal
# 1       31-Mar-19   12:36:58   ...      0  normal
# 2       31-Mar-19    12:36:58  ...      0  normal
# 3       31-Mar-19    12:37:00  ...      0  normal
# 4       31-Mar-19    12:37:01  ...      0  normal
# ...           ...         ...  ...    ...     ...
# 287189  29-Apr-19    23:59:10  ...      0  normal
# 287190  29-Apr-19    23:59:22  ...      0  normal
# 287191  29-Apr-19    23:59:26  ...      0  normal
# 287192  29-Apr-19    23:59:32  ...      0  normal
# 287193  29-Apr-19    23:59:36  ...      0  normal
#
# [287194 rows x 8 columns]

# %%
print(data.shape)
print("No of rows",data.shape[0])
print("No of columns",data.shape[1])
# Out:
# (287194, 8)
# No of rows 287194
# No of columns 8

# %%
inputs = data.drop(['label','type'],axis = 'columns')
target_var = data['label']
inputs
# Out:
#              date        time  ...  FC3_Read_Holding_Register  FC4_Read_Coil
# 0       31-Mar-19   12:36:55   ...                      33518          23014
# 1       31-Mar-19   12:36:58   ...                      26004          50645
# 2       31-Mar-19    12:36:58  ...                      26004          50645
# 3       31-Mar-19    12:37:00  ...                      33460          44046
# 4       31-Mar-19    12:37:01  ...                      33460          44046
# ...           ...         ...  ...                        ...            ...
# 287189  29-Apr-19    23:59:10  ...                      14335          58610
# 287190  29-Apr-19    23:59:22  ...                      63613          45660
# 287191  29-Apr-19    23:59:26  ...                       3792          17705
# 287192  29-Apr-19    23:59:32  ...                       3792          17705
# 287193  29-Apr-19    23:59:36  ...                      57092          39921
#
# [287194 rows x 6 columns]

# %%
le_date = LabelEncoder()
le_time = LabelEncoder()
le_FC1_Read_Input_Register = LabelEncoder()
le_FC2_Read_Discrete_Value = LabelEncoder()
le_FC3_Read_Holding_Register = LabelEncoder()
le_FC4_Read_Coil = LabelEncoder()

# %%
inputs['date_n'] = le_date.fit_transform(inputs['date'])
inputs['time_n'] = le_time.fit_transform(inputs['time'])
inputs['FC1_Read_Input_Register_n'] = le_FC1_Read_Input_Register.fit_transform(inputs['FC1_Read_Input_Register'])
inputs['FC2_Read_Discrete_Value_n'] = le_FC2_Read_Discrete_Value.fit_transform(inputs['FC2_Read_Discrete_Value'])
inputs['FC3_Read_Holding_Register_n'] = le_FC3_Read_Holding_Register.fit_transform(inputs['FC3_Read_Holding_Register'])
inputs['FC4_Read_Coil_n'] = le_FC4_Read_Coil.fit_transform(inputs['FC4_Read_Coil'])
inputs.head()
# Out:
#         date        time  ...  FC3_Read_Holding_Register_n  FC4_Read_Coil_n
# 0  31-Mar-19   12:36:55   ...                        27347            18833
# 1  31-Mar-19   12:36:58   ...                        21194            41548
# 2  31-Mar-19    12:36:58  ...                        21194            41548
# 3  31-Mar-19    12:37:00  ...                        27302            36114
# 4  31-Mar-19    12:37:01  ...                        27302            36114
#
# [5 rows x 12 columns]

# %%
new_inputs = inputs.drop(['date','time','FC1_Read_Input_Register','FC2_Read_Discrete_Value','FC3_Read_Holding_Register','FC4_Read_Coil'],axis = 'columns')
new_inputs.head()
# Out:
#    date_n  time_n  ...  FC3_Read_Holding_Register_n  FC4_Read_Coil_n
# 0      11   30945  ...                        27347            18833
# 1      11   30948  ...                        21194            41548
# 2      11   78022  ...                        21194            41548
# 3      11   78024  ...                        27302            36114
# 4      11   78025  ...                        27302            36114
#
# [5 rows x 6 columns]

# %%
#split dataset in features and target variable
feature_cols = ['date_n','time_n','FC1_Read_Input_Register_n','FC2_Read_Discrete_Value_n','FC3_Read_Holding_Register_n','FC4_Read_Coil_n']
X = new_inputs[feature_cols] # Features
y = target_var # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(6,5),random_state=5,verbose=True,learning_rate_init=0.01)


# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 0.29384290
# Iteration 2, loss = 0.24828485
# Iteration 3, loss = 0.24714829
# Iteration 4, loss = 0.24523027
# Iteration 5, loss = 0.24473999
# Iteration 6, loss = 0.24381179
# Iteration 7, loss = 0.24309693
# Iteration 8, loss = 0.24319273
# Iteration 9, loss = 0.24315003
# Iteration 10, loss = 0.21471071
# Iteration 11, loss = 0.13683208
# Iteration 12, loss = 0.12493276
# Iteration 13, loss = 0.12009857
# Iteration 14, loss = 0.11524673
# Iteration 15, loss = 0.10929829
# Iteration 16, loss = 0.10689056
# Iteration 17, loss = 0.10337740
# Iteration 18, loss = 0.10233195
# Iteration 19, loss = 0.09986198
# Iteration 20, loss = 0.10006666
# Iteration 21, loss = 0.10005048
# Iteration 22, loss = 0.09837621
# Iteration 23, loss = 0.09784577
# Iteration 24, loss = 0.09693808
# Iteration 25, loss = 0.09625125
# Iteration 26, loss = 0.09522487
# Iteration 27, loss = 0.09626825
# Iteration 28, loss = 0.09582142
# Iteration 29, loss = 0.09468721
# Iteration 30, loss = 0.09491043
# Iteration 31, loss = 0.09509870
# Iteration 32, loss = 0.09342822
# Iteration 33, loss = 0.09418998
# Iteration 34, loss = 0.09371296
# Iteration 35, loss = 0.09308751
# Iteration 36, loss = 0.09397301
# Iteration 37, loss = 0.09353902
# Iteration 38, loss = 0.09227603
# Iteration 39, loss = 0.09200593
# Iteration 40, loss = 0.09044809
# Iteration 41, loss = 0.08914592
# Iteration 42, loss = 0.08927352
# Iteration 43, loss = 0.08841848
# Iteration 44, loss = 0.08946592
# Iteration 45, loss = 0.08858848
# Iteration 46, loss = 0.08905753
# Iteration 47, loss = 0.08833920
# Iteration 48, loss = 0.08840441
# Iteration 49, loss = 0.08793779
# Iteration 50, loss = 0.08758151
# Iteration 51, loss = 0.08648264
# Iteration 52, loss = 0.08730900
# Iteration 53, loss = 0.08714617
# Iteration 54, loss = 0.08630751
# Iteration 55, loss = 0.08638776
# Iteration 56, loss = 0.08680901
# Iteration 57, loss = 0.08694056
# Iteration 58, loss = 0.08583347
# Iteration 59, loss = 0.08594568
# Iteration 60, loss = 0.08590088
# Iteration 61, loss = 0.08508658
# Iteration 62, loss = 0.08627109
# Iteration 63, loss = 0.08562654
# Iteration 64, loss = 0.08577770
# Iteration 65, loss = 0.08550098
# Iteration 66, loss = 0.08592062
# Iteration 67, loss = 0.08566809
# Iteration 68, loss = 0.08543576
# Iteration 69, loss = 0.08547818
# Iteration 70, loss = 0.08478985
# Iteration 71, loss = 0.08516616
# Iteration 72, loss = 0.08490843
# Iteration 73, loss = 0.08512394
# Iteration 74, loss = 0.08515554
# Iteration 75, loss = 0.08537464
# Iteration 76, loss = 0.08499863
# Iteration 77, loss = 0.08397795
# Iteration 78, loss = 0.08488479
# Iteration 79, loss = 0.08492872
# Iteration 80, loss = 0.08428929
# Iteration 81, loss = 0.08544780
# Iteration 82, loss = 0.08414214
# Iteration 83, loss = 0.08496502
# Iteration 84, loss = 0.08504822
# Iteration 85, loss = 0.08456700
# Iteration 86, loss = 0.08495943
# Iteration 87, loss = 0.08541161
# Iteration 88, loss = 0.08502980
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9702758852818626

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['True Positive','False Positive','False Negative','True Negative']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(conf_matrix, annot=labels, fmt="", cmap='Blues')
ax.xaxis.set_ticklabels([1,0])
ax.yaxis.set_ticklabels([1,0])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     66947
#            1       0.94      0.93      0.93     19212
#
#     accuracy                           0.97     86159
#    macro avg       0.96      0.96      0.96     86159
# weighted avg       0.97      0.97      0.97     86159

# %%
#IoT Motion Light
data = pd.read_csv('/content/drive/MyDrive/ToN_IoT_dataset/Processed_IoT_dataset/IoT_Motion_Light.csv')

# %%
data
# Out:
#              date        time  motion_status light_status  label    type
# 0       31-Mar-19    12:36:52              1           on      0  normal
# 1       31-Mar-19    12:36:53              0          off      0  normal
# 2       31-Mar-19    12:36:54              0          off      0  normal
# 3       31-Mar-19    12:36:55              1           on      0  normal
# 4       31-Mar-19    12:36:56              1           on      0  normal
# ...           ...         ...            ...          ...    ...     ...
# 452257  27-Apr-19   12:41:14               0          off      0  normal
# 452258  27-Apr-19   12:41:18               0          off      0  normal
# 452259  27-Apr-19   12:41:19               1           on      0  normal
# 452260  27-Apr-19   12:41:19               1           on      0  normal
# 452261  27-Apr-19   12:41:20               0          off      0  normal
#
# [452262 rows x 6 columns]

# %%
print(data.shape)
print("No of rows",data.shape[0])
print("No of columns",data.shape[1])
# Out:
# (452262, 6)
# No of rows 452262
# No of columns 6

# %%
inputs = data.drop(['label','type'],axis = 'columns')
target_var = data['label']
inputs
# Out:
#              date        time  motion_status light_status
# 0       31-Mar-19    12:36:52              1           on
# 1       31-Mar-19    12:36:53              0          off
# 2       31-Mar-19    12:36:54              0          off
# 3       31-Mar-19    12:36:55              1           on
# 4       31-Mar-19    12:36:56              1           on
# ...           ...         ...            ...          ...
# 452257  27-Apr-19   12:41:14               0          off
# 452258  27-Apr-19   12:41:18               0          off
# 452259  27-Apr-19   12:41:19               1           on
# 452260  27-Apr-19   12:41:19               1           on
# 452261  27-Apr-19   12:41:20               0          off
#
# [452262 rows x 4 columns]

# %%
le_date = LabelEncoder()
le_time = LabelEncoder()
le_motion_status = LabelEncoder()
le_light_status = LabelEncoder()

# %%
inputs['date_n'] = le_date.fit_transform(inputs['date'])
inputs['time_n'] = le_time.fit_transform(inputs['time'])
inputs['motion_status_n'] = le_motion_status.fit_transform(inputs['motion_status'])
inputs['light_status_n'] = le_light_status.fit_transform(inputs['light_status'])

inputs.head()
# Out:
#         date      time  motion_status  ... time_n  motion_status_n  light_status_n
# 0  31-Mar-19  12:36:52              1  ...  79113                1               1
# 1  31-Mar-19  12:36:53              0  ...  79114                0               0
# 2  31-Mar-19  12:36:54              0  ...  79115                0               0
# 3  31-Mar-19  12:36:55              1  ...  79116                1               1
# 4  31-Mar-19  12:36:56              1  ...  79117                1               1
#
# [5 rows x 8 columns]

# %%
new_inputs = inputs.drop(['date','time','motion_status','light_status'],axis = 'columns')
new_inputs.head()
# Out:
#    date_n  time_n  motion_status_n  light_status_n
# 0      10   79113                1               1
# 1      10   79114                0               0
# 2      10   79115                0               0
# 3      10   79116                1               1
# 4      10   79117                1               1

# %%
#split dataset in features and target variable
feature_cols = ['date_n','time_n','motion_status_n','light_status_n']
X = new_inputs[feature_cols] # Features
y = target_var # Target variable

# %%
 #Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
# Create Decision Tree classifer object
clf = MLPClassifier(hidden_layer_sizes=(6,5),random_state=5,verbose=True,learning_rate_init=0.01)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 0.14798133
# Iteration 2, loss = 0.09152350
# Iteration 3, loss = 0.08117417
# Iteration 4, loss = 0.07225182
# Iteration 5, loss = 0.06987230
# Iteration 6, loss = 0.06940914
# Iteration 7, loss = 0.06883588
# Iteration 8, loss = 0.06445645
# Iteration 9, loss = 0.05997593
# Iteration 10, loss = 0.05887024
# Iteration 11, loss = 0.05853018
# Iteration 12, loss = 0.05744076
# Iteration 13, loss = 0.05881258
# Iteration 14, loss = 0.05747797
# Iteration 15, loss = 0.05835167
# Iteration 16, loss = 0.05783317
# Iteration 17, loss = 0.05768133
# Iteration 18, loss = 0.05756408
# Iteration 19, loss = 0.05724342
# Iteration 20, loss = 0.05724753
# Iteration 21, loss = 0.05735575
# Iteration 22, loss = 0.05738968
# Iteration 23, loss = 0.05717231
# Iteration 24, loss = 0.05750142
# Iteration 25, loss = 0.05701455
# Iteration 26, loss = 0.05690316
# Iteration 27, loss = 0.05710860
# Iteration 28, loss = 0.05753987
# Iteration 29, loss = 0.05648402
# Iteration 30, loss = 0.05684896
# Iteration 31, loss = 0.05656308
# Iteration 32, loss = 0.05692949
# Iteration 33, loss = 0.05710846
# Iteration 34, loss = 0.05693891
# Iteration 35, loss = 0.05727209
# Iteration 36, loss = 0.05689952
# Iteration 37, loss = 0.05670048
# Iteration 38, loss = 0.05662235
# Iteration 39, loss = 0.05663006
# Iteration 40, loss = 0.05722186
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9764001798362311

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['True Pos','False Pos','False Neg','True Neg']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(conf_matrix, annot=labels, fmt="", cmap='Blues')
ax.xaxis.set_ticklabels([1,0])
ax.yaxis.set_ticklabels([1,0])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99    116449
#            1       0.90      0.93      0.92     19230
#
#     accuracy                           0.98    135679
#    macro avg       0.95      0.96      0.95    135679
# weighted avg       0.98      0.98      0.98    135679

# %%
#IoT Thermostat
data = pd.read_csv('/content/drive/MyDrive/ToN_IoT_dataset/Processed_IoT_dataset/IoT_Thermostat.csv')

# %%
data
# Out:
#              date        time  ...  label    type
# 0       31-Mar-19    12:36:52  ...      0  normal
# 1       31-Mar-19    12:36:53  ...      0  normal
# 2       31-Mar-19    12:36:54  ...      0  normal
# 3       31-Mar-19    12:36:55  ...      0  normal
# 4       31-Mar-19    12:36:56  ...      0  normal
# ...           ...         ...  ...    ...     ...
# 442223  27-Apr-19   12:41:14   ...      0  normal
# 442224  27-Apr-19   12:41:18   ...      0  normal
# 442225  27-Apr-19   12:41:19   ...      0  normal
# 442226  27-Apr-19   12:41:19   ...      0  normal
# 442227  27-Apr-19   12:41:20   ...      0  normal
#
# [442228 rows x 6 columns]

# %%
print(data.shape)
print("No of rows",data.shape[0])
print("No of columns",data.shape[1])
# Out:
# (442228, 6)
# No of rows 442228
# No of columns 6

# %%
data = data.dropna(axis = 0,subset=['date', 'time'])

# %%
inputs = data.drop(['label','type'],axis = 'columns')
target_var = data['label']
inputs
# Out:
#              date        time  current_temperature  thermostat_status
# 0       31-Mar-19    12:36:52            25.000000                  0
# 1       31-Mar-19    12:36:53            25.000000                  0
# 2       31-Mar-19    12:36:54            25.000000                  0
# 3       31-Mar-19    12:36:55            25.000000                  0
# 4       31-Mar-19    12:36:56            25.000000                  0
# ...           ...         ...                  ...                ...
# 442223  27-Apr-19   12:41:14             29.804525                  1
# 442224  27-Apr-19   12:41:18             25.824332                  1
# 442225  27-Apr-19   12:41:19             27.248819                  1
# 442226  27-Apr-19   12:41:19             29.739201                  1
# 442227  27-Apr-19   12:41:20             29.658987                  1
#
# [437607 rows x 4 columns]

# %%
le_date = LabelEncoder()

le_time = LabelEncoder()
le_current_temperature = LabelEncoder()
le_thermostat_status = LabelEncoder()

# %%
inputs['date_n'] = le_date.fit_transform(inputs['date'].astype('str'))
inputs['time_n'] = le_time.fit_transform(inputs['time'].astype('str'))
inputs['current_temperature_n'] = le_current_temperature.fit_transform(inputs['current_temperature'].astype('str'))
inputs['thermostat_status_n'] = le_thermostat_status.fit_transform(inputs['thermostat_status'].astype('str'))

inputs.head()
# Out:
#         date      time  ...  current_temperature_n  thermostat_status_n
# 0  31-Mar-19  12:36:52  ...                      0                    0
# 1  31-Mar-19  12:36:53  ...                      0                    0
# 2  31-Mar-19  12:36:54  ...                      0                    0
# 3  31-Mar-19  12:36:55  ...                      0                    0
# 4  31-Mar-19  12:36:56  ...                      0                    0
#
# [5 rows x 8 columns]

# %%
new_inputs = inputs.drop(['date','time','current_temperature','thermostat_status'],axis = 'columns')
new_inputs.head()
# Out:
#    date_n  time_n  current_temperature_n  thermostat_status_n
# 0      10   79408                      0                    0
# 1      10   79409                      0                    0
# 2      10   79410                      0                    0
# 3      10   79411                      0                    0
# 4      10   79412                      0                    0

# %%
#split dataset in features and target variable
feature_cols = ['date_n','time_n','current_temperature_n','thermostat_status_n']
X = new_inputs[feature_cols] # Features
y = target_var # Target variable

# %%
#Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(6,5),random_state=5,verbose=True,learning_rate_init=0.01)


# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 0.08803372
# Iteration 2, loss = 0.04697601
# Iteration 3, loss = 0.04340846
# Iteration 4, loss = 0.04364804
# Iteration 5, loss = 0.04253863
# Iteration 6, loss = 0.04174330
# Iteration 7, loss = 0.04093684
# Iteration 8, loss = 0.04186416
# Iteration 9, loss = 0.04070058
# Iteration 10, loss = 0.04114327
# Iteration 11, loss = 0.04049553
# Iteration 12, loss = 0.04027370
# Iteration 13, loss = 0.04024568
# Iteration 14, loss = 0.03963692
# Iteration 15, loss = 0.04007549
# Iteration 16, loss = 0.03971526
# Iteration 17, loss = 0.04015309
# Iteration 18, loss = 0.03972642
# Iteration 19, loss = 0.03915263
# Iteration 20, loss = 0.03851795
# Iteration 21, loss = 0.03855609
# Iteration 22, loss = 0.03833168
# Iteration 23, loss = 0.03820143
# Iteration 24, loss = 0.03791968
# Iteration 25, loss = 0.03770436
# Iteration 26, loss = 0.03786251
# Iteration 27, loss = 0.03740711
# Iteration 28, loss = 0.03739021
# Iteration 29, loss = 0.03724028
# Iteration 30, loss = 0.03668885
# Iteration 31, loss = 0.03672932
# Iteration 32, loss = 0.03687363
# Iteration 33, loss = 0.03671449
# Iteration 34, loss = 0.03653493
# Iteration 35, loss = 0.03660014
# Iteration 36, loss = 0.03649553
# Iteration 37, loss = 0.03625995
# Iteration 38, loss = 0.03601700
# Iteration 39, loss = 0.03635123
# Iteration 40, loss = 0.03606750
# Iteration 41, loss = 0.03580274
# Iteration 42, loss = 0.03594562
# Iteration 43, loss = 0.03591962
# Iteration 44, loss = 0.03589829
# Iteration 45, loss = 0.03577996
# Iteration 46, loss = 0.03592734
# Iteration 47, loss = 0.03566539
# Iteration 48, loss = 0.03588623
# Iteration 49, loss = 0.03521174
# Iteration 50, loss = 0.03524966
# Iteration 51, loss = 0.03455903
# Iteration 52, loss = 0.03271955
# Iteration 53, loss = 0.03190617
# Iteration 54, loss = 0.03132600
# Iteration 55, loss = 0.03070871
# Iteration 56, loss = 0.03045643
# Iteration 57, loss = 0.02959364
# Iteration 58, loss = 0.02946794
# Iteration 59, loss = 0.02931414
# Iteration 60, loss = 0.02898211
# Iteration 61, loss = 0.02878891
# Iteration 62, loss = 0.02901550
# Iteration 63, loss = 0.02828898
# Iteration 64, loss = 0.02817139
# Iteration 65, loss = 0.02763540
# Iteration 66, loss = 0.02857365
# Iteration 67, loss = 0.02761445
# Iteration 68, loss = 0.02788178
# Iteration 69, loss = 0.02719267
# Iteration 70, loss = 0.02754152
# Iteration 71, loss = 0.02757766
# Iteration 72, loss = 0.02792118
# Iteration 73, loss = 0.02703617
# Iteration 74, loss = 0.02684525
# Iteration 75, loss = 0.02708272
# Iteration 76, loss = 0.02631222
# Iteration 77, loss = 0.02671513
# Iteration 78, loss = 0.02680448
# Iteration 79, loss = 0.02635186
# Iteration 80, loss = 0.02646854
# Iteration 81, loss = 0.02650756
# Iteration 82, loss = 0.02608544
# Iteration 83, loss = 0.02630618
# Iteration 84, loss = 0.02614102
# Iteration 85, loss = 0.02647295
# Iteration 86, loss = 0.02579424
# Iteration 87, loss = 0.02610870
# Iteration 88, loss = 0.02598350
# Iteration 89, loss = 0.02555065
# Iteration 90, loss = 0.02646774
# Iteration 91, loss = 0.02564456
# Iteration 92, loss = 0.02602450
# Iteration 93, loss = 0.02606705
# Iteration 94, loss = 0.02587616
# Iteration 95, loss = 0.02599170
# Iteration 96, loss = 0.02609111
# Iteration 97, loss = 0.02574092
# Iteration 98, loss = 0.02562851
# Iteration 99, loss = 0.02529239
# Iteration 100, loss = 0.02564960
# Iteration 101, loss = 0.02532607
# Iteration 102, loss = 0.02566409
# Iteration 103, loss = 0.02566879
# Iteration 104, loss = 0.02540310
# Iteration 105, loss = 0.02574272
# Iteration 106, loss = 0.02523184
# Iteration 107, loss = 0.02521488
# Iteration 108, loss = 0.02549737
# Iteration 109, loss = 0.02528559
# Iteration 110, loss = 0.02595235
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9909965494389982

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['True Pos','False Pos','False Neg','True Neg']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(conf_matrix, annot=labels, fmt="", cmap='Blues')
ax.xaxis.set_ticklabels([1,0])
ax.yaxis.set_ticklabels([1,0])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    114423
#            1       0.95      0.98      0.97     16860
#
#     accuracy                           0.99    131283
#    macro avg       0.97      0.99      0.98    131283
# weighted avg       0.99      0.99      0.99    131283

# %%
#IoT Weather
data = pd.read_csv('/content/drive/MyDrive/ToN_IoT_dataset/Processed_IoT_dataset/IoT_Weather.csv')

# %%
data
# Out:
#              date        time  temperature  pressure   humidity  label    type
# 0       31-Mar-19    12:36:52    31.788508  1.035000  32.036579      0  normal
# 1       31-Mar-19    12:36:53    41.630997  1.035000  30.886165      0  normal
# 2       31-Mar-19    12:36:54    42.256959  1.035000  19.755908      0  normal
# 3       31-Mar-19    12:36:55    49.116581  1.035000  78.949621      0  normal
# 4       31-Mar-19    12:36:56    24.017085  1.035000  40.001059      0  normal
# ...           ...         ...          ...       ...        ...    ...     ...
# 650237  27-Apr-19   12:41:17     40.384291  9.049059  93.094490      0  normal
# 650238  27-Apr-19   12:41:18     47.240113 -5.782022  28.146511      0  normal
# 650239  27-Apr-19   12:41:18     23.540606  0.913648  30.478316      0  normal
# 650240  27-Apr-19   12:41:18     46.016150  3.493588  73.328413      0  normal
# 650241  27-Apr-19   12:41:20     48.082975  0.100271  20.949148      0  normal
#
# [650242 rows x 7 columns]

# %%
print(data.shape)
print("No of rows",data.shape[0])
print("No of columns",data.shape[1])
# Out:
# (650242, 7)
# No of rows 650242
# No of columns 7

# %%
inputs = data.drop(['label','type'],axis = 'columns')
target_var = data['label']
inputs
# Out:
#              date        time  temperature  pressure   humidity
# 0       31-Mar-19    12:36:52    31.788508  1.035000  32.036579
# 1       31-Mar-19    12:36:53    41.630997  1.035000  30.886165
# 2       31-Mar-19    12:36:54    42.256959  1.035000  19.755908
# 3       31-Mar-19    12:36:55    49.116581  1.035000  78.949621
# 4       31-Mar-19    12:36:56    24.017085  1.035000  40.001059
# ...           ...         ...          ...       ...        ...
# 650237  27-Apr-19   12:41:17     40.384291  9.049059  93.094490
# 650238  27-Apr-19   12:41:18     47.240113 -5.782022  28.146511
# 650239  27-Apr-19   12:41:18     23.540606  0.913648  30.478316
# 650240  27-Apr-19   12:41:18     46.016150  3.493588  73.328413
# 650241  27-Apr-19   12:41:20     48.082975  0.100271  20.949148
#
# [650242 rows x 5 columns]

# %%
le_date = LabelEncoder()
le_time = LabelEncoder()
le_temperature = LabelEncoder()
le_pressure = LabelEncoder()
le_humidity = LabelEncoder()

# %%
inputs['date_n'] = le_date.fit_transform(inputs['date'])
inputs['time_n'] = le_time.fit_transform(inputs['time'])
inputs['temperature_n'] = le_temperature.fit_transform(inputs['temperature'])
inputs['pressure_n'] = le_pressure.fit_transform(inputs['pressure'])
inputs['humidity_n'] = le_humidity.fit_transform(inputs['humidity'])
inputs.head()
# Out:
#         date      time  temperature  ...  temperature_n  pressure_n  humidity_n
# 0  31-Mar-19  12:36:52    31.788508  ...         187945       32817       29574
# 1  31-Mar-19  12:36:53    41.630997  ...         388149       32817       28321
# 2  31-Mar-19  12:36:54    42.256959  ...         402748       32817       16911
# 3  31-Mar-19  12:36:55    49.116581  ...         562045       32817       83485
# 4  31-Mar-19  12:36:56    24.017085  ...          53759       32817       38182
#
# [5 rows x 10 columns]

# %%
new_inputs = inputs.drop(['date','time','temperature','pressure','humidity'],axis = 'columns')
new_inputs.head()
# Out:
#    date_n  time_n  temperature_n  pressure_n  humidity_n
# 0      11   77572         187945       32817       29574
# 1      11   77573         388149       32817       28321
# 2      11   77574         402748       32817       16911
# 3      11   77575         562045       32817       83485
# 4      11   77576          53759       32817       38182

# %%
#split dataset in features and target variable
feature_cols = ['date_n', 'time_n', 'temperature_n', 'pressure_n', 'humidity_n']
X = new_inputs[feature_cols] # Features
y = target_var # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10) # 70% training and 30% test

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(6,5),random_state=5,verbose=True,learning_rate_init=0.01)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# Iteration 1, loss = 0.13509350
# Iteration 2, loss = 0.08382678
# Iteration 3, loss = 0.08100096
# Iteration 4, loss = 0.08040638
# Iteration 5, loss = 0.07750827
# Iteration 6, loss = 0.07742237
# Iteration 7, loss = 0.07611692
# Iteration 8, loss = 0.07601294
# Iteration 9, loss = 0.07554429
# Iteration 10, loss = 0.07535139
# Iteration 11, loss = 0.07483889
# Iteration 12, loss = 0.07483888
# Iteration 13, loss = 0.07412848
# Iteration 14, loss = 0.07345136
# Iteration 15, loss = 0.07319080
# Iteration 16, loss = 0.07291741
# Iteration 17, loss = 0.07280408
# Iteration 18, loss = 0.07266918
# Iteration 19, loss = 0.07220315
# Iteration 20, loss = 0.07216050
# Iteration 21, loss = 0.07200381
# Iteration 22, loss = 0.07197389
# Iteration 23, loss = 0.07185618
# Iteration 24, loss = 0.07231409
# Iteration 25, loss = 0.07203531
# Iteration 26, loss = 0.07148752
# Iteration 27, loss = 0.07150056
# Iteration 28, loss = 0.07115564
# Iteration 29, loss = 0.07140763
# Iteration 30, loss = 0.07130065
# Iteration 31, loss = 0.07145483
# Iteration 32, loss = 0.07147671
# Iteration 33, loss = 0.07082889
# Iteration 34, loss = 0.07110165
# Iteration 35, loss = 0.07145571
# Iteration 36, loss = 0.07108928
# Iteration 37, loss = 0.07118722
# Iteration 38, loss = 0.07089320
# Iteration 39, loss = 0.07098676
# Iteration 40, loss = 0.07066960
# Iteration 41, loss = 0.07104595
# Iteration 42, loss = 0.07101564
# Iteration 43, loss = 0.07065409
# Iteration 44, loss = 0.07110872
# Iteration 45, loss = 0.07029735
# Iteration 46, loss = 0.07059636
# Iteration 47, loss = 0.07066350
# Iteration 48, loss = 0.07059624
# Iteration 49, loss = 0.07061035
# Iteration 50, loss = 0.07051994
# Iteration 51, loss = 0.07049903
# Iteration 52, loss = 0.07058868
# Iteration 53, loss = 0.07003710
# Iteration 54, loss = 0.06974649
# Iteration 55, loss = 0.06946672
# Iteration 56, loss = 0.06936199
# Iteration 57, loss = 0.06951219
# Iteration 58, loss = 0.06918507
# Iteration 59, loss = 0.06933420
# Iteration 60, loss = 0.06944570
# Iteration 61, loss = 0.06944603
# Iteration 62, loss = 0.06934283
# Iteration 63, loss = 0.06951971
# Iteration 64, loss = 0.06954609
# Iteration 65, loss = 0.06914893
# Iteration 66, loss = 0.06936103
# Iteration 67, loss = 0.06934925
# Iteration 68, loss = 0.06954392
# Iteration 69, loss = 0.06944103
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9670789909418526

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['True Pos','False Pos','False Neg','True Neg']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(conf_matrix, annot=labels, fmt="", cmap='Blues')
ax.xaxis.set_ticklabels([1,0])
ax.yaxis.set_ticklabels([1,0])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98    168084
#            1       0.81      0.99      0.89     26989
#
#     accuracy                           0.97    195073
#    macro avg       0.91      0.98      0.94    195073
# weighted avg       0.97      0.97      0.97    195073
